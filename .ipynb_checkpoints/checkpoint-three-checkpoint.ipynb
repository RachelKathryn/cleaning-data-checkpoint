# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/nationalparkservice/park-biodiversity
#
# Import the necessary libraries and create your dataframe(s).

# %%
# Importing pandas, numpy, and seaborn.

import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the parks CSV.

parks = pd.read_csv("parks.csv")

# %%
# Reading the species CSV. When I use the code __species = pd.read_csv("species.csv")__ I receive the error:
#  "DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False."

species = pd.read_csv("species.csv", dtype={"Species ID":str, "Park Name":str, "Category":str, "Order":str, "Family":str, "Scientific Name":str, "Common Names":str, "Record Status":str, "Occurrence":str, "Nativeness": str, "Abundance":str, "Seasonality":str, "Conservation Status":str,"Unnamed: 13":str})

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# Looking for duplicate values in the parks dataset.

parks_dupes = parks.duplicated()

parks_dupes.sum()
# Out:
# 0

# %%
# Looking for duplicate values in the species dataset.

species_dupes = species.duplicated()

species_dupes.sum()
# Out:
# 0

# %%
# Dropping the unnecessary column identified in EDA.

species = species.drop(['Unnamed: 13'], axis=1)

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# Using .isnull() to determine the number of null values across columns in the parks dataset.

parks.isnull().sum()
# Out:
# Park Code    0
# Park Name    0
# State        0
# Acres        0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
# Using .isnull() to determine the number of null values across columns in the species dataset.

species.isnull().sum()
# Out:
# Species ID                  0
# Park Name                   0
# Category                    0
# Order                    1472
# Family                   1512
# Scientific Name             0
# Common Names                0
# Record Status               0
# Occurrence              20142
# Nativeness              25045
# Abundance               42942
# Seasonality             99091
# Conservation Status    114530
# dtype: int64

# %%
# Checking the percentage of null values across columns. 

percent_missing_species = species.isnull().sum() * 100 / len(species)

percent_missing_species
# Out:
# Species ID              0.000000
# Park Name               0.000000
# Category                0.000000
# Order                   1.234402
# Family                  1.267946
# Scientific Name         0.000000
# Common Names            0.000000
# Record Status           0.000000
# Occurrence             16.890849
# Nativeness             21.002449
# Abundance              36.010667
# Seasonality            83.096572
# Conservation Status    96.043540
# dtype: float64

# %%
# Checking the percentages of values in the Occurrence column to see if there is a clear mode and if I can impute. 

(species['Occurrence'].value_counts())/(species['Occurrence'].value_counts().sum()) * 100

# While the majority of values are 'Present', I'm cautious about imputing missing values with the mode 
# given my business question.
# Out:
# Present                            84.029221
# Not Confirmed                      12.065869
# Not Present (False Report)          2.090691
# Not Present (Historical Report)     1.321817
# Not Present                         0.434888
# Approved                            0.051460
# In Review                           0.006054
# Name: Occurrence, dtype: float64

# %%
# Checking the percentages of values in the Nativeness column to see if there is a clear mode and if I can impute. 

(species['Nativeness'].value_counts())/(species['Nativeness'].value_counts().sum()) * 100

# While the majority of values are 'Native', I'm cautious about imputing missing values with the mode 
# given my business question.
# Out:
# Native           80.623759
# Not Native       11.777757
# Unknown           7.537976
# Present           0.056261
# Not Confirmed     0.004246
# Name: Nativeness, dtype: float64

# %%
# Checking the percentages of values in the Abundance column to see if there is a clear mode and if I can impute. 

(species['Abundance'].value_counts())/(species['Abundance'].value_counts().sum()) * 100

# No clear mode. Will not be imputing, especially given the amount of missing data.
# Out:
# Unknown       36.850313
# Uncommon      24.610122
# Common        16.922654
# Rare          14.111603
# Occasional     4.340419
# Abundant       3.099363
# Native         0.052421
# Not Native     0.013105
# Name: Abundance, dtype: float64

# %%
# Checking the percentages of values in the Seasonality column to see if there is a clear mode and if I can impute. 

(species['Seasonality'].value_counts())/(species['Seasonality'].value_counts().sum()) * 100

# While the majority of values are 'Breeder', I'm cautious about imputing missing values with the mode 
# given my business question. Also choosing not to impute given the amount of missing data.
# Out:
# Breeder                                 60.594334
# Resident                                15.949794
# Migratory                               14.014982
# Vagrant                                  8.235352
# Breeder, Winter                          0.317508
# Rare                                     0.173637
# Summer                                   0.128987
# Migratory, Winter                        0.119065
# Winter                                   0.099221
# Breeder, Resident                        0.099221
# Breeder, Migratory                       0.064494
# Resident, Winter                         0.044650
# Uncommon                                 0.024805
# Common                                   0.019844
# Migratory, Vagrant                       0.019844
# Summer, Vagrant                          0.014883
# Breeder, Resident, Summer                0.014883
# Migratory, Summer                        0.014883
# Unknown                                  0.014883
# Resident, Summer                         0.009922
# Breeder, Summer                          0.009922
# Breeder, Resident, Migratory, Summer     0.004961
# Breeder, Resident, Summer, Winter        0.004961
# Winter, Vagrant                          0.004961
# Name: Seasonality, dtype: float64

# %%
# Checking the percentages of values in the Conservation Status column to see if there is a clear mode and if I 
# can impute. 

(species['Conservation Status'].value_counts())/(species['Conservation Status'].value_counts().sum()) * 100

# While the majority of values are 'Species of Concern', I'm cautious about imputing missing values with the mode 
# given my business question. Wondering if those who collected the data left this column blank for species that are 
# relatively common (i.e., Why record Conservation Status if there is nothing notable?)
# Also choosing not to impute given the amount of missing data.
# Out:
# Species of Concern     81.454006
# Endangered              7.927088
# Under Review            4.111912
# Threatened              3.899958
# In Recovery             1.632047
# Proposed Endangered     0.508690
# Proposed Threatened     0.148368
# Breeder                 0.148368
# Resident                0.105977
# Migratory               0.042391
# Extinct                 0.021195
# Name: Conservation Status, dtype: float64

# %%
# Given the above results, I'm choosing to handle remaining missing data by filling with "_MISSING_". 
# If I choose to use these columns in later analysis I'll note that results should be interpreted with varying 
# levels of caution based on the amount of _MISSING_ values. 

species['Order'] = species['Order'].fillna('_MISSING_')
species['Family'] = species['Family'].fillna('_MISSING_')
species['Occurrence'] = species['Occurrence'].fillna('_MISSING_')
species['Nativeness'] = species['Nativeness'].fillna('_MISSING_')
species['Abundance'] = species['Abundance'].fillna('_MISSING_')
species['Seasonality'] = species['Seasonality'].fillna('_MISSING_')
species['Conservation Status'] = species['Conservation Status'].fillna('_MISSING_')

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# Determining Acre outliers in the Parks dataset. 

sns.boxplot(y=parks["Acres"]);
plt.show()

# Even though there are several parks that are significantly larger than the majority, I will not be 
# removing these parks from my dataset as that would be counterintuitive given the business question!

# %%
# Determining Latitude outliers in the Parks dataset. 

sns.boxplot(y=parks["Latitude"]);
plt.show()

# Even though there are a handful of parks that are significantly farther North than the majority, I will not be 
# removing these parks from my dataset as that would be counterintuitive given the business question!

# %%
# Determining Longitude outliers in the Parks dataset. 

sns.boxplot(y=parks["Longitude"]);
plt.show()

# Even though there are a handful of parks that are significantly farther East and West than the majority, I will 
# not be removing these parks from my dataset as that would be counterintuitive given the business question!

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
# Determining the number of unique values for the variables with string data in the parks dataset. 

parks.nunique()
# Out:
# Park Code    56
# Park Name    56
# State        27
# Acres        55
# Latitude     53
# Longitude    55
# dtype: int64

# %%
# Converting all the parks strings in a column to lowercase to ensure consistency.

parks = parks.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
# Checking the results to see if there were upper/lowercase inconsistencies.

parks.nunique()

# Looks like there weren't any hidden duplicates that contained inconsistently formatted data.
# Out:
# Park Code    56
# Park Name    56
# State        27
# Acres        55
# Latitude     53
# Longitude    55
# dtype: int64

# %%
# In my EDA I discovered some of the rows in the species dataset were misaligned. Checking the values in the 
# Record Status column to determine what the misaligned values are.

species['Record Status'].value_counts()
# Out:
# Approved                86254
# In Review               32937
# None                        6
#  Willowherb                 1
#  Devil's Shoelaces          1
#  Verdolagas                 1
#  Chico                      1
#  Skyrocket Gilia            1
#  Grass-Leaf Loco            1
#  Golden Pea                 1
#  Storksbill                 1
#  Cranesbill                 1
#  Speedwell                  1
#  Common Mullein             1
#  Downy Chess                1
#  Wiregrass                  1
#  Leather Flower             1
#  Shadbush                   1
#  Wild Rose                  1
#  Skunkbush                  1
#  Clover Bush                1
#  Kinnikinnick               1
#  Filaree                    1
#  Liver Leaf*                1
#  *                          1
#  Whortleberry               1
#  Claret Cup                 1
#  Goosefoot                  1
#  Cenizo                     1
#  Bluebell                   1
#  Purple Cockle              1
#  Dames Rocket               1
#  Manati                     1
#  Ranchers' Fireweed         1
#  Cocodrilo De Tumbes        1
#  Cabezon                    1
#  Wapiti                     1
#  Short-Tailed Weasel        1
#  White-Footed Mouse         1
#  Northern Goshawk           1
#  Northern Pintail           1
#  Common Poorwill            1
#  Pigeon Hawk                1
#  Bushtit                    1
#  American Crow              1
#  Catbird                    1
#  Robin                      1
#  Speckled Trout             1
#  Osha                       1
#  Wild Iris                  1
#  Fringed Sage               1
#  Rushpink                   1
#  Ground Daisy               1
# P.Nut Sedge                 1
# Name: Record Status, dtype: int64

# %%
# Locating the rows that contain the misaligned data.

species.loc[species['Record Status'].isin([" Willowherb", " Devil's Shoelaces", " Verdolagas", " Chico", " Skyrocket Gilia", " Grass-Leaf Loco", " Golden Pea", " Storksbill", " Cranesbill", " Speedwell", " Common Mullein", " Downy Chess", " Wiregrass", " Leather Flower", " Shadbush", " Wild Rose", " Skunkbush", "Clover Bush", " Kinnikinnick", " Filaree", " Liver Leaf*", " *", " Whortleberry", " Claret Cup", " Goosefoot", " Cenizo", " Bluebell", " Purple Cockle", " Dames Rocket", " Manati", " Ranchers' Fireweed", " Cocodrilo De Tumbes", " Cabezon", " Wapiti", " Short-Tailed Weasel", " White-Footed Mouse", " Northern Goshawk", " Northern Pintail", " Common Poorwill", " Pigeon Hawk", " Bushtit", " American Crow", " Catbird", " Robin", " Speckled Trout", " Osha", " Wild Iris", " Fringed Sage", " Rushpink", " Ground Daisy", "P.Nut Sedge"])]
# Out:
#       Species ID                                    Park Name        Category  \
# 812    ACAD-1812                         Acadia National Park  Vascular Plant
# 3280   BADL-1523                       Badlands National Park  Vascular Plant
# 6441   BISC-1026                       Biscayne National Park          Mammal
# 27484  DEVA-2399                   Death Valley National Park  Vascular Plant
# 31786  EVER-1414                     Everglades National Park         Reptile
# 31826  EVER-1454                     Everglades National Park         Reptile
# 44600  GRSA-1003  Great Sand Dunes National Park and Preserve          Mammal
# 44610  GRSA-1013  Great Sand Dunes National Park and Preserve          Mammal
# 44640  GRSA-1043  Great Sand Dunes National Park and Preserve          Mammal
# 44666  GRSA-1069  Great Sand Dunes National Park and Preserve            Bird
# 44678  GRSA-1081  Great Sand Dunes National Park and Preserve            Bird
# 44705  GRSA-1108  Great Sand Dunes National Park and Preserve            Bird
# 44733  GRSA-1136  Great Sand Dunes National Park and Preserve            Bird
# 44744  GRSA-1147  Great Sand Dunes National Park and Preserve            Bird
# 44759  GRSA-1162  Great Sand Dunes National Park and Preserve            Bird
# 44818  GRSA-1221  Great Sand Dunes National Park and Preserve            Bird
# 44859  GRSA-1262  Great Sand Dunes National Park and Preserve            Bird
# 44924  GRSA-1327  Great Sand Dunes National Park and Preserve            Fish
# 44933  GRSA-1336  Great Sand Dunes National Park and Preserve  Vascular Plant
# 44944  GRSA-1347  Great Sand Dunes National Park and Preserve  Vascular Plant
# 44968  GRSA-1371  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45018  GRSA-1421  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45060  GRSA-1463  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45064  GRSA-1467  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45114  GRSA-1517  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45115  GRSA-1518  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45127  GRSA-1530  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45158  GRSA-1561  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45169  GRSA-1572  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45170  GRSA-1573  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45194  GRSA-1597  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45210  GRSA-1613  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45220  GRSA-1623  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45240  GRSA-1643  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45241  GRSA-1644  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45272  GRSA-1675  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45279  GRSA-1682  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45312  GRSA-1715  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45367  GRSA-1770  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45402  GRSA-1805  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45473  GRSA-1876  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45492  GRSA-1895  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45521  GRSA-1924  Great Sand Dunes National Park and Preserve  Vascular Plant
# 45529  GRSA-1932  Great Sand Dunes National Park and Preserve  Vascular Plant
# 53164  GRTE-1992                    Grand Teton National Park  Vascular Plant
# 53307  GRTE-2135                    Grand Teton National Park  Vascular Plant
# 79001  MORA-1681                  Mount Rainier National Park  Vascular Plant
# 79013  MORA-1693                  Mount Rainier National Park  Vascular Plant
# 79016  MORA-1696                  Mount Rainier National Park  Vascular Plant
# 98533  SAGU-2429                        Saguaro National Park  Vascular Plant
#
#                   Order            Family  \
# 812      Caryophyllales   Caryophyllaceae
# 3280        Brassicales      Brassicaceae
# 6441            Sirenia      Trichechidae
# 27484       Boraginales      Boraginaceae
# 31786        Crocodilia      Crocodylidae
# 31826        Testudines       Cheloniidae
# 44600      Artiodactyla          Cervidae
# 44610         Carnivora        Mustelidae
# 44640          Rodentia        Cricetidae
# 44666   Accipitriformes      Accipitridae
# 44678      Anseriformes          Anatidae
# 44705  Caprimulgiformes     Caprimulgidae
# 44733     Falconiformes        Falconidae
# 44744     Passeriformes      Aegithalidae
# 44759     Passeriformes          Corvidae
# 44818     Passeriformes           Mimidae
# 44859     Passeriformes          Turdidae
# 44924     Salmoniformes        Salmonidae
# 44933           Apiales          Apiaceae
# 44944       Asparagales         Iridaceae
# 44968         Asterales        Asteraceae
# 45018         Asterales        Asteraceae
# 45060         Asterales        Asteraceae
# 45064         Asterales     Campanulaceae
# 45114    Caryophyllales     Amaranthaceae
# 45115    Caryophyllales     Amaranthaceae
# 45127    Caryophyllales         Cactaceae
# 45158    Caryophyllales      Polygonaceae
# 45169    Caryophyllales     Portulacaceae
# 45170    Caryophyllales     Sarcobataceae
# 45194          Ericales     Polemoniaceae
# 45210           Fabales          Fabaceae
# 45220           Fabales          Fabaceae
# 45240        Geraniales       Geraniaceae
# 45241        Geraniales       Geraniaceae
# 45272          Lamiales    Plantaginaceae
# 45279          Lamiales  Scrophulariaceae
# 45312          Myrtales        Onagraceae
# 45367            Poales         Juncaceae
# 45402            Poales           Poaceae
# 45473      Ranunculales     Ranunculaceae
# 45492           Rosales          Rosaceae
# 45521           Rosales          Rosaceae
# 45529        Sapindales     Anacardiaceae
# 53164          Ericales         Ericaceae
# 53307        Geraniales       Geraniaceae
# 79001          Ericales         Ericaceae
# 79013          Ericales         Ericaceae
# 79016          Ericales         Ericaceae
# 98533            Poales        Cyperaceae
#
#                               Scientific Name           Common Names  \
# 812                        Agrostemma githago            Corn Cockle
# 3280                      Hesperis matronalis          Dame's Rocket
# 6441                       Trichechus manatus                Manatee
# 27484                     Amsinckia menziesii             Fiddleneck
# 31786                       Crocodylus acutus     American Crocodile
# 31826                         Caretta caretta             Loggerhead
# 44600                          Cervus elaphus           American Elk
# 44610                         Mustela erminea                 Ermine
# 44640                  Peromyscus maniculatus             Deer Mouse
# 44666                      Accipiter gentilis                Goshawk
# 44678                              Anas acuta                Pintail
# 44705                Phalaenoptilus nuttallii              Poor-Will
# 44733                       Falco columbarius                 Merlin
# 44744                    Psaltriparus minimus         Common Bushtit
# 44759                   Corvus brachyrhynchos            Common Crow
# 44818                  Dumetella carolinensis           Gray Catbird
# 44859                      Turdus migratorius         American Robin
# 44924                   Salvelinus fontinalis            Brook Trout
# 44933                      Ligusticum porteri                 Lovage
# 44944                      Iris missouriensis              Blue Flag
# 44968                       Artemisia frigida           Pasture Sage
# 45018                       Lygodesmia juncea           Skeletonweed
# 45060                      Townsendia exscapa           Easter Daisy
# 45064                  Campanula rotundifolia        Common Harebell
# 45114                      Atriplex canescens  Four Winged Saltbrush
# 45115                       Chenopodium album        Lamb's Quarters
# 45127            Echinocereus triglochidiatus        Hedgehog Cactus
# 45158                     Polygonum aviculare               Knotweed
# 45169                      Portulaca oleracea        Common Purslane
# 45170                 Sarcobatus vermiculatus       Black Greasewood
# 45194                     Ipomopsis aggregata          Scarlet Gilia
# 45210                    Astragalus ceramicus            Painted Pod
# 45220                  Thermopsis divaricarpa          Golden Banner
# 45240                      Erodium cicutarium                Filaree
# 45241                    Geranium caespitosum        Common Geranium
# 45272                      Veronica americana     American Brooklime
# 45279                       Verbascum thapsus          Great Mullein
# 45312                 Chamerion angustifolium               Fireweed
# 45367                         Juncus balticus            Baltic Rush
# 45402                         Bromus tectorum             Cheatgrass
# 45473                   Clematis hirsutissima             Sugarbowls
# 45492                   Amelanchier alnifolia    Common Serviceberry
# 45521                            Rosa woodsii            Wood's Rose
# 45529                          Rhus trilobata              Squawbush
# 53164  Arctostaphylos uva-ursi var. stipitata              Bearberry
# 53307                      Erodium cicutarium             Storksbill
# 79001       Pyrola asarifolia ssp. asarifolia          Alpine Pyrola
# 79013                   Vaccinium ovalifolium  Tall Blue Huckleberry
# 79016                     Vaccinium scoparium            Grouseberry
# 98533                        Cyperus rotundus       Purple Nut Grass
#
#               Record Status Occurrence     Nativeness   Abundance Seasonality  \
# 812           Purple Cockle   Approved  Not Confirmed  Not Native   _MISSING_
# 3280           Dames Rocket   Approved        Present  Not Native        Rare
# 6441                 Manati   Approved        Present     Unknown     Unknown
# 27484    Ranchers' Fireweed   Approved        Present      Native     Unknown
# 31786   Cocodrilo De Tumbes   Approved        Present      Native    Uncommon
# 31826               Cabezon   Approved        Present      Native        Rare
# 44600                Wapiti   Approved        Present      Native        Rare
# 44610   Short-Tailed Weasel   Approved        Present      Native        Rare
# 44640    White-Footed Mouse   Approved        Present      Native        Rare
# 44666      Northern Goshawk   Approved        Present      Native        Rare
# 44678      Northern Pintail   Approved        Present      Native        Rare
# 44705       Common Poorwill   Approved        Present      Native    Uncommon
# 44733           Pigeon Hawk   Approved        Present      Native        Rare
# 44744               Bushtit   Approved        Present      Native    Uncommon
# 44759         American Crow   Approved        Present      Native        Rare
# 44818               Catbird   Approved        Present      Native        Rare
# 44859                 Robin   Approved        Present      Native      Common
# 44924        Speckled Trout   Approved        Present  Not Native      Common
# 44933                  Osha   Approved        Present      Native        Rare
# 44944             Wild Iris   Approved        Present      Native        Rare
# 44968          Fringed Sage   Approved        Present      Native        Rare
# 45018              Rushpink   Approved        Present      Native        Rare
# 45060          Ground Daisy   Approved        Present      Native        Rare
# 45064              Bluebell   Approved        Present      Native        Rare
# 45114                Cenizo   Approved        Present      Native        Rare
# 45115             Goosefoot   Approved        Present  Not Native        Rare
# 45127            Claret Cup   Approved        Present      Native        Rare
# 45158     Devil's Shoelaces   Approved  Not Confirmed      Native   _MISSING_
# 45169            Verdolagas   Approved  Not Confirmed  Not Native   _MISSING_
# 45170                 Chico   Approved        Present      Native        Rare
# 45194       Skyrocket Gilia   Approved        Present      Native        Rare
# 45210       Grass-Leaf Loco   Approved        Present      Native        Rare
# 45220            Golden Pea   Approved        Present      Native        Rare
# 45240            Storksbill   Approved        Present  Not Native        Rare
# 45241            Cranesbill   Approved        Present      Native        Rare
# 45272             Speedwell   Approved        Present      Native        Rare
# 45279        Common Mullein   Approved  Not Confirmed  Not Native   _MISSING_
# 45312            Willowherb   Approved        Present      Native        Rare
# 45367             Wiregrass   Approved        Present      Native        Rare
# 45402           Downy Chess   Approved        Present  Not Native        Rare
# 45473        Leather Flower   Approved        Present      Native        Rare
# 45492              Shadbush   Approved        Present      Native        Rare
# 45521             Wild Rose   Approved        Present      Native        Rare
# 45529             Skunkbush   Approved        Present      Native        Rare
# 53164          Kinnikinnick   Approved        Present      Native    Uncommon
# 53307               Filaree   Approved        Present  Not Native    Uncommon
# 79001           Liver Leaf*   Approved        Present      Native        Rare
# 79013                     *   Approved        Present      Native      Common
# 79016          Whortleberry   Approved        Present      Native      Common
# 98533           P.Nut Sedge   Approved        Present  Not Native     Unknown
#
#       Conservation Status
# 812             _MISSING_
# 3280            _MISSING_
# 6441            _MISSING_
# 27484           _MISSING_
# 31786            Resident
# 31826             Breeder
# 44600           Migratory
# 44610           Migratory
# 44640             Breeder
# 44666             Breeder
# 44678            Resident
# 44705             Breeder
# 44733            Resident
# 44744             Breeder
# 44759            Resident
# 44818            Resident
# 44859             Breeder
# 44924             Breeder
# 44933           _MISSING_
# 44944           _MISSING_
# 44968           _MISSING_
# 45018           _MISSING_
# 45060           _MISSING_
# 45064           _MISSING_
# 45114           _MISSING_
# 45115           _MISSING_
# 45127           _MISSING_
# 45158           _MISSING_
# 45169           _MISSING_
# 45170           _MISSING_
# 45194           _MISSING_
# 45210           _MISSING_
# 45220           _MISSING_
# 45240           _MISSING_
# 45241           _MISSING_
# 45272           _MISSING_
# 45279           _MISSING_
# 45312           _MISSING_
# 45367           _MISSING_
# 45402           _MISSING_
# 45473           _MISSING_
# 45492           _MISSING_
# 45521           _MISSING_
# 45529           _MISSING_
# 53164           _MISSING_
# 53307           _MISSING_
# 79001           _MISSING_
# 79013           _MISSING_
# 79016           _MISSING_
# 98533           _MISSING_

# %%
# Dropping the rows with misaligned data. I could write code to move the values down a column so that they were 
# correctly aligned but without knowing the specific contraints of the dataset (i.e., which specific values are 
# associated with each column) I'm hesitant to correct the rows manually. 

species.drop([812, 3280, 6441, 27484, 31786, 31826, 44600, 44610, 44640, 44666, 44678, 44705, 44733, 44744, 44759, 44818, 44859, 44924, 44933, 44944, 44968, 45018, 45060, 45064, 45114, 45115, 45127, 45158, 45169, 45170, 45194, 45210, 45220, 45240, 45241, 45272, 45279, 45312, 45367, 45402, 45473, 45492, 45521, 45529, 45535, 53164, 53307, 79001, 79013, 79016, 98533
], axis=0, inplace=True)

# %%
# Checking to see if the misaligned rows were successfuly dropped.

species['Record Status'].value_counts()
# Out:
# Approved     86254
# In Review    32937
# None             6
# Name: Record Status, dtype: int64

# %%
# Determining the number of unique values for the variables with string data in the species dataset. 

species.nunique()
# Out:
# Species ID             119197
# Park Name                  56
# Category                   14
# Order                     555
# Family                   2333
# Scientific Name         46021
# Common Names            35812
# Record Status               3
# Occurrence                  7
# Nativeness                  5
# Abundance                   7
# Seasonality                21
# Conservation Status         9
# dtype: int64

# %%
# Converting all the species strings in a column to lowercase to ensure consistency.

species = species.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
# Checking the results to see if there were upper/lowercase inconsistencies.

species.nunique()

# Looks like there weren't any hidden duplicates that contained inconsistently formatted data.
# Out:
# Species ID             119197
# Park Name                  56
# Category                   14
# Order                     555
# Family                   2333
# Scientific Name         46019
# Common Names            35812
# Record Status               3
# Occurrence                  7
# Nativeness                  5
# Abundance                   7
# Seasonality                21
# Conservation Status         9
# dtype: int64

# %%
# Finally, I'm going to change the column names in the parks dataset to remove spaces. 

parks = parks.rename(columns={'Park Code': 'Park_Code', 'Park Name': 'Park_Name'})

# %%
# Finally, I'm going to change the column names in the parks dataset to remove spaces. 

species = species.rename(columns={'Species ID': 'Species_ID', 'Park Name': 'Park_Name', 'Scientific Name': 'Scientific_Name', 'Common Names': 'Common_Names', 'Record Status': 'Record_Status', 'Conservation Status': 'Conservation_Status'})

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
#
# The Species dataset had quite a bit of missing data, no irregular data, and some inconsistent data due to the data being misaligned with the columns for several species. Because some of the data were misaligned, the dataset also inluded an unnecessary column, which I dropped.
#
# The Parks dataset did not have dirty data.
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
#
# Not really! I didn't learn too much more than what I learned from EDA.
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
#
# I replaced a lot of missing values in several columns with "_MISSING_". If I choose to visualize data using these columns I'll have to use caution when interpreting / presenting the results.
